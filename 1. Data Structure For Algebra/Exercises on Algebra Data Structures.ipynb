# %%
# Selesaikan soal berikut
import PIL.Image as Image

img = Image.open('C:/Users/lwnovo/Documents/VSCode/Github/Data Structur For Algebra/image.png')
img.show()

import numpy as np

mitra_np = np.array([[25], [2], [-3], [-23]])
print(mitra_np)

print()

# transporse dari mitra_np menjadi mitra_t
mitra_t = mitra_np.T
print(f"Hasil Transpose dari mitra_np adlalah : {mitra_t}")
# Out:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
#
# Hasil Transpose dari mitra_np adlalah : [[ 25   2  -3 -23]]
