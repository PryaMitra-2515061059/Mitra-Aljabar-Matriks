# %%
# Selesaikan soal berikut
import PIL.Image as Image

img = Image.open('C:/Users/lwnovo/Documents/VSCode/Github/Data Structur For Algebra/image.png')
img.show()

import numpy as np

np = np.array([[25], [2], [-3], [-23]])
print(np)

print()

# transporse dari np menjadi t
t = np.T
print(f"Hasil Transpose dari np adlalah : {t}")
# Out:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
#
# Hasil Transpose dari np adlalah : [[ 25   2  -3 -23]]
