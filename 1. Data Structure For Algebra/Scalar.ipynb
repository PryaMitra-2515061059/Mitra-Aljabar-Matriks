# %% [markdown]
# ## No 1

# %%
# buat variabel skalar x dan simpan Ssuatu nilai skalar
x = 13
print(x)
# Out:
# 13

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 17
print(y)
# Out:
# 17

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
sum = x + y
print(sum)
# Out:
# 30

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal 
x_float = 13.7
float_sum = x_float + y
print(float_sum)
# Out:
# 30.7

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# ## No 2

# %%
import tensorflow as tf

# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# buat variabel skalar x dan simpan nilai skalar serta tipe datanya
x_tf = tf.Variable(13, dtype = tf.int32)
print(x_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=13>

# %%
# buat variabel skalar y dan simpan nilai skalar serta tipe datanya
y_tf = tf.Variable(17, dtype = tf.int32)
print(y_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=17>

# %%
# jumlahkan x_tf + y_tf
tf_sum = tf.add(x_tf, y_tf)
print(tf_sum)
# Out:
# tf.Tensor(30, shape=(), dtype=int32)

# %%
# buat variabel bernama x_float_tf dan simpan suatu nilai desimal serta tipe datanya
x_float_tf = tf.Variable(13.7, dtype = tf.float32)
print(x_float_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=13.699999809265137>

# %% [markdown]
# ## No 3

# %%
import torch as pt

# lakukan tahapan pada soal 1 dengan menggunakan pytorch

# buat variabel skalar x dan simpan nilai skalar serta tipe datanya
x_pt = pt.tensor(13, dtype = pt.int32)
print(x_pt)
# Out:
# tensor(13, dtype=torch.int32)

# %%
# buat variabel skalar y dan simpan nilai skalar serta tipe datanya
y_pt = pt.tensor(17, dtype = pt.int32)
print(y_pt)
# Out:
# tensor(17, dtype=torch.int32)

# %%
# jumlahkan x_pt + y_pt
pt_sum = pt.add(x_pt, y_pt)
print(pt_sum)
# Out:
# tensor(30, dtype=torch.int32)

# %%
# buat variabel bernama x_float_pt dan simpan suatu nilai desimal serta tipe datanya
x_float_pt = pt.tensor(13.7, dtype = pt.float32)
print(x_float_pt)
# Out:
# tensor(13.7000)
